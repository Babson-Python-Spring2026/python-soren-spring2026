# %% [markdown]
# # Tic-Tac-Toe Lab — Practice Exercises
#
# These exercises build the pieces you need for the full Tic-Tac-Toe lab.
#
# Assume:
# - X always goes first
# - The board is a 3x3 grid

# %% [markdown]
# ## Exercise 1 — Create an Empty Board
# Write a function `create_board()` that returns a 3x3 board filled with empty spaces (`' '`).

# %%
# Your code here
def create_board():

# %% [markdown]
# ## Exercise 2 — Display the Board
# Write a function `display_board(board)` that prints the board in a readable 3x3 format.

# %%
# Your code here
from utils.functions import clear_screen
def display_board(board: list[int]) -> None:

'''
Display the Tic-Tac-Toe board.
Args:
board: List of 9 integers (10 for X, -10 for O, 1-9 for open).
'''

def cell(value: int) -> str:
    if value == 10: return 'X'
    elif value == -10: return 'O'
    else: return str(value)
    clear_screen()
    print()

for row in range(3):
    row_values = [cell(board[row * 3 + col]) for col in range(3)]
    print(' | | ')
    print(f' {row_values[0]} | {row_values[1]} | {row_values[2]} ')
    print(' | | ')
    if row < 2:
        print('-----------')
        print()
        board = [10,2,3,4,5,6,7,8,-10]
        display_board(board)
# Out:
#   Cell In[1], line 4
#     '''
#     ^
# IndentationError: expected an indented block after function definition on line 3

# %% [markdown]
# ## Exercise 3 — Count X and O
# Write a function `count_symbols(board)` that returns a tuple `(x_count, o_count)`.

# %%
# Your code here
def count_symbols(board):
    x_count = 0
    o_count = 0
    x_count = board.count(10)
    o_count = board.count(-10)

    return x_count, o_count

# %% [markdown]
# ## Exercise 4 — Derive Current Player
# Using `count_symbols(board)`, write `current_player(board)` that returns `'X'` or `'O'`.

# %%
# Your code here
def current_player(board):
    status = count_symbols(board)

    if status[0] - status[1] == 0: return 'X'
    elif status[0] - status[1] == 1: return 'O'

print(current_player(board))

# %% [markdown]
# ## Exercise 5 — Validate Move
# Write `is_valid_move(board, row, col)` that returns True if the square is empty and within bounds.

# %%
# Your code here
square = 3
def is_valid_move(board, square):

    if not board:
        print('FATAL ERROR: no board')
        exit()
        
    square_idx = square - 1

    if (square_idx < 0 or square_idx > 8) and square_idx != 10: return False

    elif board[square_idx] in [10,-10]: False
    return True

# %% [markdown]
# ## Exercise 6 — Place a Move (Transition)
# Write `place_move(board, row, col, player)` that mutates the board.

# %%
# Your code here

def place_ove(board, space):
    symbol = current_player(board)

    if symbol == 'X': target = 10
    else: target = -10

    square_idx = square - 1

    if is_valid_move(board, square):
        board[square_idx] = target

    else:

# %% [markdown]
# ## Exercise 7 — Check Rows for Winner
# Write `check_rows(board)` that returns `'X'`, `'O'`, or None.

# %%
# Your code here

# %% [markdown]
# ## Exercise 8 — Check Columns and Diagonals
# Extend your winner logic to include columns and diagonals.

# %%
# Your code here

# %% [markdown]
# ## Exercise 9 — Check Draw
# Write `check_draw(board)` that returns True if the board is full and no winner exists.

# %%
# Your code here

# %% [markdown]
# ## Exercise 10 — Game Over Wrapper
# Write `game_over(board)` that returns True if there is a winner or draw.

# %%
# Your code here
