# %% [markdown]
# # Recursion In-Class Exercises
#
# Complete each function **recursively**.
#
# For each problem, identify:
# - the **base case**
# - the **smaller problem**
# - what should happen **before** or **after** the recursive call

# %% [markdown]
# ## 1. Countdown
#
# Write a recursive function `countdown(n)` that prints numbers from `n` down to `1`, and then prints `"blastoff"`.
#
# Example:
#
# ```python
# countdown(5)
# ```
#
# Output:
#
# ```text
# 5
# 4
# 3
# 2
# 1
# blastoff
# ```

# %%
def countdown(n):
    if n == 0:
        print("blastoff")
        
    else:
        print(n)
        countdown(n - 1)
    pass

countdown(5)
# Out:
# 5
# 4
# 3
# 2
# 1
# blastoff

# %% [markdown]
# ## 2. Factorial
#
# Write a recursive function `factorial(n)` that returns `n!`.
#
# Recall:
#
# ```text
# 5! = 5 * 4 * 3 * 2 * 1
# ```
#
# Example:
#
# ```python
# factorial(5)
# ```
#
# should return:
#
# ```text
# 120
# ```

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)
    pass

num = 5
print(num)
print(factorial(num))
# Out:
# 5
# 120

# %% [markdown]
# ## 3. Palindrome
#
# Write a recursive function `palindrome(txt)` that returns `True` if `txt` is a palindrome and `False` otherwise.
#
# A palindrome reads the same forward and backward.
#
# Examples:
#
# ```python
# palindrome("level")   # True
# palindrome("levels")  # False
# ```

# %%
def palindrome(txt):
    if len(txt) <= 1:
        True
    
    if txt[0] != txt[-1]:
        return False
    
    return palindrome(txt[1:-1])
    pass

# %% [markdown]
# ## 4. Print List
#
# Write a recursive function `print_list(L)` that prints each element of the list on its own line.
#
# Example:
#
# ```python
# print_list([1, 2, 3, 4])
# ```
#
# Output:
#
# ```text
# 1
# 2
# 3
# 4
# ```

# %%
L = [1,2,3,4]
def print_list(L):
    if len(L) == 0: return

    print(L[0])

    return print_list(L[1:])
print_list(L)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ## 5. Count Up
#
# Write a recursive function `countup(n)` that prints numbers from `1` up to `n`.
#
# Use recursion to make the numbers appear in increasing order.
#
# Example:
#
# ```python
# countup(5)
# ```
#
# Output:
#
# ```text
# blastoff
# 1
# 2
# 3
# 4
# 5
# ```

# %%
def countup(n):
    if n == 0:
        print('blastoff')
    else:
        countup(n-1)
        print(n)
    pass
countup(5)
# Out:
# blastoff
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## 6. Fibonacci
#
# Write a recursive function `fib(n)` using this definition:
#
# ```text
# fib(1) = 0
# fib(2) = 1
# fib(n) = fib(n-1) + fib(n-2)
# ```
#
# Example:
#
# ```python
# fib(10)
# ```
#
# should return:
#
# ```text
# 34
# ```

# %%
def fib(n):
    if n == 1: return 0
    if n == 2: return 1

    return fib(n-1) + fib(n-2)
    pass
print(fib(10))
# Out:
# 34

# %% [markdown]
# ## 7. Sum Digits
#
# Write a recursive function `sum_digits(n)` that returns the sum of the digits of `n`.
#
# Example:
#
# ```python
# sum_digits(583)
# ```
#
# should return:
#
# ```text
# 16
# ```
#
# Hint:
# - last digit: `n % 10`
# - remaining number: `n // 10`

# %%
def sum_digits(n):
    pass

# %% [markdown]
# ## 8. Reverse String
#
# Write a recursive function `reverse_string(txt)` that returns the reverse of the string.
#
# Example:
#
# ```python
# reverse_string("hello")
# ```
#
# should return:
#
# ```text
# 'olleh'
# ```

# %%
def reverse_string(txt):
    pass

# %% [markdown]
# ## 9. Count Characters
#
# Write a recursive function `count_chars(txt)` that counts the number of characters in a string.
#
# Do **not** use `len`.
#
# Example:
#
# ```python
# count_chars("the")
# ```
#
# should return:
#
# ```text
# 3
# ```

# %%
def count_chars(txt):
    pass

# %% [markdown]
# ## 10. Convert to Binary
#
# Write a recursive function `to_binary(n)` that returns the binary representation of `n` as a string.
#
# Example:
#
# ```python
# to_binary(30)
# ```
#
# should return:
#
# ```text
# '11110'
# ```
#
# Hint:
#
# ```python
# # binary(n) = binary(n // 2) + str(n % 2)
# ```
#
# Useful idea:
# - `n % 2` gives the last binary digit
# - `n // 2` removes that digit and gives the smaller problem

# %%
def to_binary(n):
    pass
